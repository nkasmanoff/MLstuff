# %%
from nba_py import player
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %% [markdown]
# Try to use an RNN to characterize player progression, identify the peak of a players career, MVP predictions, etc.

# %%
def get_PID(first_name,last_name):
    """Obtains the player ID number of the desired player.
    
    Parameters
    -----------
    
    first_name: str
        First name of player
    last_name: str
        Last name of player
    
    Returns
    -------
    
    ID : float
        The player's ID number. 
    """
    
    playa = player.get_player(first_name=first_name,last_name=last_name)
    
    return playa.values[0]

# %%
mj = get_PID('Michael','Jordan')
lbj = get_PID('Lebron','James')

MJ = player.PlayerCareer(player_id=mj)
LBJ = player.PlayerCareer(player_id=lbj)

# %%
LBJPPS =player.PlayerVsPlayer

# %%
LBJPPS =player.PlayerVsPlayer

# %%
LBJPPS.overall()
# Out:
#   GROUP_SET GROUP_VALUE  GP   W   L  W_PCT   MIN   FGM   FGA  FG_PCT  FG3M  \
# 0   Overall     2017-18  82  50  32   0.61  36.9  10.5  19.3   0.542   1.8
#
#    FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  TOV  STL  BLK  BLKA  \
# 0   5.0    0.367  4.7  6.5   0.731   1.2   7.5  8.6  9.1  4.2  1.4  0.9   0.8
#
#     PF  PFD   PTS  PLUS_MINUS  NBA_FANTASY_PTS  DD2  TD3  GP_RANK  W_RANK  \
# 0  1.7  5.4  27.5         1.3             54.1   52   18        1       1
#
#    L_RANK  W_PCT_RANK  MIN_RANK  FGM_RANK  FGA_RANK  FG_PCT_RANK  FG3M_RANK  \
# 0       1           1         1         1         1            1          1
#
#    FG3A_RANK  FG3_PCT_RANK  FTM_RANK  FTA_RANK  FT_PCT_RANK  OREB_RANK  \
# 0          1             1         1         1            1          1
#
#    DREB_RANK  REB_RANK  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  \
# 0          1         1         1         1         1         1          1
#
# ...

# %%
MJ.regular_season_career_totals()
# Out:
#    PLAYER_ID LEAGUE_ID  Team_ID    GP    GS   MIN   FGM   FGA  FG_PCT  FG3M  \
# 0        893        00        0  1072  1039  38.3  11.4  22.9   0.497   0.5
#
#    FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0   1.7    0.327  6.8  8.2   0.835   1.6   4.7  6.2  5.3  2.3  0.8  2.7  2.6
#
#     PTS
# 0  30.1

# %%
LBJ.regular_season_career_totals()
# Out:
#    PLAYER_ID LEAGUE_ID  Team_ID    GP    GS   MIN  FGM   FGA  FG_PCT  FG3M  \
# 0       2544        00        0  1143  1142  38.8  9.9  19.6   0.504   1.4
#
#    FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0   4.1    0.344  6.0  8.1   0.739   1.2   6.1  7.4  7.2  1.6  0.8  3.5  1.8
#
#     PTS
# 0  27.2

# %%
LBJ.regular_season_totals()
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0        2544   2003-04        00  1610612739               CLE        19.0
# 1        2544   2004-05        00  1610612739               CLE        20.0
# 2        2544   2005-06        00  1610612739               CLE        21.0
# 3        2544   2006-07        00  1610612739               CLE        22.0
# 4        2544   2007-08        00  1610612739               CLE        23.0
# 5        2544   2008-09        00  1610612739               CLE        24.0
# 6        2544   2009-10        00  1610612739               CLE        25.0
# 7        2544   2010-11        00  1610612748               MIA        26.0
# 8        2544   2011-12        00  1610612748               MIA        27.0
# 9        2544   2012-13        00  1610612748               MIA        28.0
# 10       2544   2013-14        00  1610612748               MIA        29.0
# ...

# %%
    playa = player.get_player(first_name=first_name,last_name=last_name)

# %%
player.get_player(first_name='Joel',last_name='Embiid')
# Out:
# 1083    203954
# Name: PERSON_ID, dtype: int64

# %%
lebron = player.PlayerCareer(player_id=2544)

# %%
lebron.post_season_career_totals()
# Out:
#    PLAYER_ID LEAGUE_ID  Team_ID   GP   GS   MIN   FGM   FGA  FG_PCT  FG3M  \
# 0       2544        00        0  227  227  42.0  10.2  20.8   0.488   1.5
#
#    ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF   PTS
# 0  ...    0.743   1.5   7.3  8.9  6.9  1.8  1.0  3.5  2.4  28.7
#
# [1 rows x 24 columns]

# %%
lbjD = player.PlayerDefenseTracking(player_id=2544,last_n_games=3)

# %%
lbjD.overall()
# Out:
#    CLOSE_DEF_PERSON_ID  GP  G    DEFENSE_CATEGORY  FREQ  D_FGM  D_FGA  \
# 0                 2544   3  3             Overall  1.00   4.67   8.33
# 1                 2544   3  3          3 Pointers  0.44   1.33   3.67
# 2                 2544   3  3          2 Pointers  0.56   3.33   4.67
# 3                 2544   3  2      Less Than 6 Ft  0.20   1.33   1.67
# 4                 2544   3  3     Less Than 10 Ft  0.28   1.67   2.33
# 5                 2544   3  3  Greater Than 15 Ft  0.68   2.67   5.67
#
#    D_FG_PCT  NORMAL_FG_PCT  PCT_PLUSMINUS
# 0     0.560          0.473          0.087
# 1     0.364          0.386         -0.023
# 2     0.714          0.518          0.196
# 3     0.800          0.633          0.167
# 4     0.714          0.566          0.148
# 5     0.471          0.414          0.057

# %%
embiid = 203954

# %%
embiidD = player.PlayerDefenseTracking(player_id=embiid,last_n_games=11)

# %%
embiidD.overall()
# Out:
#    CLOSE_DEF_PERSON_ID  GP  G    DEFENSE_CATEGORY   FREQ  D_FGM  D_FGA  \
# 0               203954   3  3             Overall  1.000   4.00  13.00
# 1               203954   3  2          3 Pointers  0.179   0.67   2.33
# 2               203954   3  3          2 Pointers  0.821   3.33  10.67
# 3               203954   3  3      Less Than 6 Ft  0.462   2.00   6.00
# 4               203954   3  3     Less Than 10 Ft  0.564   2.33   7.33
# 5               203954   3  3  Greater Than 15 Ft  0.385   1.00   5.00
#
#    D_FG_PCT  NORMAL_FG_PCT  PCT_PLUSMINUS
# 0     0.308          0.504         -0.197
# 1     0.286          0.397         -0.111
# 2     0.313          0.539         -0.227
# 3     0.333          0.631         -0.298
# 4     0.318          0.580         -0.262
# 5     0.200          0.392         -0.192
